# %%
## words used in bike thefts
# newspaper article scraped 

import pandas as pd
import glob, os

# %%
import collections

# %%
# not a CSV file but this seems to work
data = pd.read_csv('../data/stories.txt', header = None)

# %%
# seems to be about thefts
data
# Out:
#                                                    0
# 0  Also on Stolen Bikes UK       Snow — Congrats ...

# %%
#select only alpha, convert to lowercase
import re
letters_only = re.sub('[^a-zA-Z]', ' ', data[0][0])
letters_only = letters_only.lower()
letters_only = re.sub('\s+', ' ', letters_only)

# %%
import collections
#split at whitespace
words = letters_only.split()

# %%
len(words)
# Out:
# 1499

# %%
import numpy as np
wordarray=np.asarray(words)
len(wordarray)
# Out:
# 1499

# %%
bagsofwords = [ collections.Counter(re.findall(r'\w+', txt))
            for txt in wordarray]

# %%
sumbags = sum(bagsofwords, collections.Counter())
sumbags
# Out:
# Counter({'a': 36,
#          'able': 1,
#          'about': 7,
#          'acceptable': 1,
#          'action': 1,
#          'activity': 1,
#          'actually': 1,
#          'add': 1,
#          'address': 2,
#          'advert': 1,
#          'africa': 1,
#          'after': 3,
#          'again': 4,
#          'ago': 4,
#          'all': 8,
#          'allowed': 1,
#          'almost': 1,
#          'also': 2,
#          'although': 1,
#          'am': 1,
#          'america': 1,
#          'an': 4,
#          'and': 44,
#          'angry': 1,
#          'annoyed': 1,
#          'another': 1,
#          'anti': 1,
#          'any': 3,
#          'anyone': 1,
#          'anything': 1,
#          'anyway': 1,
#          'appear': 1,
#          'approached': 1,
#          'area': 1,
#          'arm': 1,
#          'around': 1,
#          'arrange': 1,
#          'arrest': 1,
#          'arrested': 1,
#          'arrests': 1,
#          'as': 7,
#          'asked': 1,
# ...

# %%
import nltk
#TODO - remove stopwords
#stops = set(stopwords.words('english'))
#meaningful_words = [word for word in wordarray if not word in stops]
#words1 = " ".join(meaningful_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4d969ad8bac1> in <module>()
#       1 import nltk
# ----> 2 stops = set(stopwords.words('english'))
#       3 meaningful_words = [word for word in wordarray if not word in stops]
#       4 words1 = " ".join(meaningful_words)
#
# NameError: name 'stopwords' is not defined
